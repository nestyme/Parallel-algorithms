# %% [markdown]
# ### Часть 2. Построение и анализ графиков (cashes)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# %matplotlib inline
plt.style.use('fivethirtyeight')

# %%
time_differenses = np.zeros(65)
i = -1;
for line in open('output_cashe'):
    if line.strip():           
        i += 1
        try:
            n = float(line) 
            print(n)
            time_differenses[i]=n
        except ValueError:
            pass
print(i)
# Out:
# 1768.24
# 2260.12
# 2334.19
# 2717.15
# 3585.62
# 3216.4
# 2749.23
# 3862.79
# 4076.03
# 4228.83
# 4292.57
# 4466.85
# 5045.71
# 4648.26
# 4662.14
# 4908.98
# 4949.95
# 5059.68
# 6548.14
# 5416.01
# 5205.48
# 5451.96
# 5560.98
# 5929.65
# 5802.76
# 5943.58
# 5898.18
# 6199.92
# 6111.18
# 6007.09
# 6099.96
# 6268.38
# 6261.77
# 6265.86
# 6624.67
# 6445.36
# 6508.54
# 6616.56
# 6687.15
# 6893.37
# 7040.62
# 7159.38
# 7124.64
# 7383.37
# 7607.11
# 7695.34
# 8402.05
# 8186.97
# 8022.45
# 7837.71
# 8364.85
# 9040.5
# 8436.34
# 8612.51
# 8821.23
# 8866.51
# 8657.22
# 9095.31
# 9580.27
# 9352.73
# 9027.09
# 9744.22
# 10129.4
# 9485.56
# 9301.6
# 64

# %%
n = [int(x) for x in range(65)]

# %%
plt.figure(figsize=(18, 6))
print(len(n), len(time_differenses))
plt.plot(n, time_differenses, color='teal',alpha=0.7, linewidth=1.7)
plt.plot(linewidth=1)
plt.title("Time Differenses")
plt.xlabel('Iteration')
plt.ylabel("Time")
plt.show()
# Out:
# 65 65
